# %%
import pandas as  pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dataset = pd.read_csv("diabetic_data.csv")
df = pd.DataFrame(dataset)
df = df[["encounter_id","patient_nbr",'race',"gender","age","admission_type_id","discharge_disposition_id","admission_source_id","time_in_hospital","num_lab_procedures","num_procedures","num_medications","number_outpatient","number_emergency","number_inpatient","number_diagnoses","max_glu_serum","A1Cresult","glipizide","rosiglitazone","change","diabetesMed","readmitted"]
]

# %%
df.head()
# Out:
#    encounter_id  patient_nbr             race  gender      age  \
# 0       2278392      8222157        Caucasian  Female   [0-10)
# 1        149190     55629189        Caucasian  Female  [10-20)
# 2         64410     86047875  AfricanAmerican  Female  [20-30)
# 3        500364     82442376        Caucasian    Male  [30-40)
# 4         16680     42519267        Caucasian    Male  [40-50)
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital  num_lab_procedures  ...  number_emergency  \
# 0                 1                  41  ...                 0
# ...

# %%
df.tail()
# Out:
#         encounter_id  patient_nbr             race  gender      age  \
# 101761     443847548    100162476  AfricanAmerican    Male  [70-80)
# 101762     443847782     74694222  AfricanAmerican  Female  [80-90)
# 101763     443854148     41088789        Caucasian    Male  [70-80)
# 101764     443857166     31693671        Caucasian  Female  [80-90)
# 101765     443867222    175429310        Caucasian    Male  [70-80)
#
#         admission_type_id  discharge_disposition_id  admission_source_id  \
# 101761                  1                         3                    7
# 101762                  1                         4                    5
# 101763                  1                         1                    7
# 101764                  2                         3                    7
# 101765                  1                         1                    7
#
#         time_in_hospital  num_lab_procedures  ...  number_emergency  \
# ...

# %%
df.shape
# Out:
# (101766, 23)

# %%
df.describe()
# Out:
#        encounter_id   patient_nbr  admission_type_id  \
# count  1.017660e+05  1.017660e+05      101766.000000
# mean   1.652016e+08  5.433040e+07           2.024006
# std    1.026403e+08  3.869636e+07           1.445403
# min    1.252200e+04  1.350000e+02           1.000000
# 25%    8.496119e+07  2.341322e+07           1.000000
# 50%    1.523890e+08  4.550514e+07           1.000000
# 75%    2.302709e+08  8.754595e+07           3.000000
# max    4.438672e+08  1.895026e+08           8.000000
#
#        discharge_disposition_id  admission_source_id  time_in_hospital  \
# count             101766.000000        101766.000000     101766.000000
# mean                   3.715642             5.754437          4.395987
# std                    5.280166             4.064081          2.985108
# min                    1.000000             1.000000          1.000000
# 25%                    1.000000             1.000000          2.000000
# ...

# %%
df.dtypes
# Out:
# encounter_id                 int64
# patient_nbr                  int64
# race                        object
# gender                      object
# age                         object
# admission_type_id            int64
# discharge_disposition_id     int64
# admission_source_id          int64
# time_in_hospital             int64
# num_lab_procedures           int64
# num_procedures               int64
# num_medications              int64
# number_outpatient            int64
# number_emergency             int64
# number_inpatient             int64
# number_diagnoses             int64
# max_glu_serum               object
# A1Cresult                   object
# glipizide                   object
# rosiglitazone               object
# change                      object
# diabetesMed                 object
# readmitted                  object
# dtype: object

# %%
df.columns
# Out:
# Index(['encounter_id', 'patient_nbr', 'race', 'gender', 'age',
#        'admission_type_id', 'discharge_disposition_id', 'admission_source_id',
#        'time_in_hospital', 'num_lab_procedures', 'num_procedures',
#        'num_medications', 'number_outpatient', 'number_emergency',
#        'number_inpatient', 'number_diagnoses', 'max_glu_serum', 'A1Cresult',
#        'glipizide', 'rosiglitazone', 'change', 'diabetesMed', 'readmitted'],
#       dtype='object')

# %%
categorical_features=['race', 'gender', 'age',
       'admission_type_id', 'discharge_disposition_id', 'admission_source_id',
       
          'max_glu_serum', 'A1Cresult',
        'glipizide',
        'rosiglitazone', 
        'change', 'diabetesMed', 'readmitted']

df[categorical_features]=df[categorical_features].astype(str)

# %%
df.dtypes
# Out:
# encounter_id                 int64
# patient_nbr                  int64
# race                        object
# gender                      object
# age                         object
# admission_type_id           object
# discharge_disposition_id    object
# admission_source_id         object
# time_in_hospital             int64
# num_lab_procedures           int64
# num_procedures               int64
# num_medications              int64
# number_outpatient            int64
# number_emergency             int64
# number_inpatient             int64
# number_diagnoses             int64
# max_glu_serum               object
# A1Cresult                   object
# glipizide                   object
# rosiglitazone               object
# change                      object
# diabetesMed                 object
# readmitted                  object
# dtype: object

# %%
df.nunique()
# Out:
# encounter_id                101766
# patient_nbr                  71518
# race                             6
# gender                           3
# age                             10
# admission_type_id                8
# discharge_disposition_id        26
# admission_source_id             17
# time_in_hospital                14
# num_lab_procedures             118
# num_procedures                   7
# num_medications                 75
# number_outpatient               39
# number_emergency                33
# number_inpatient                21
# number_diagnoses                16
# max_glu_serum                    4
# A1Cresult                        4
# glipizide                        4
# rosiglitazone                    4
# change                           2
# diabetesMed                      2
# readmitted                       3
# dtype: int64

# %%
df=df.replace("?",np.nan)

# %%
df.isnull().sum()
# Out:
# encounter_id                   0
# patient_nbr                    0
# race                        2273
# gender                         0
# age                            0
# admission_type_id              0
# discharge_disposition_id       0
# admission_source_id            0
# time_in_hospital               0
# num_lab_procedures             0
# num_procedures                 0
# num_medications                0
# number_outpatient              0
# number_emergency               0
# number_inpatient               0
# number_diagnoses               0
# max_glu_serum                  0
# A1Cresult                      0
# glipizide                      0
# rosiglitazone                  0
# change                         0
# diabetesMed                    0
# readmitted                     0
# dtype: int64

# %%
df['race'].fillna(df['race'].mode()[0], inplace=True)

# %%
df = df.drop_duplicates(subset= ['patient_nbr'], keep = 'first')

# %%
df['facility_usage'] = df['number_outpatient'] + df['number_emergency'] + df['number_inpatient']

# %%
df=df.drop(['number_outpatient', 'number_emergency','number_inpatient'], axis = 1)

# %%
df.shape
# Out:
# (71518, 21)

# %%
df['readmitted'] = df['readmitted'].replace('>30', 1)
df['readmitted'] = df['readmitted'].replace('<30', 1)
df['readmitted'] = df['readmitted'].replace('NO', 0)

# %%
df = df.drop(df.loc[df["gender"]=="Unknown/Invalid"].index, axis=0)
df = df.drop(df.loc[df["discharge_disposition_id"]=="nan"].index, axis=0)
df = df.drop(df.loc[df["admission_source_id"]=="nan"].index, axis=0)

# %%
df["num_lab_procedures"].plot.box()
# Out:
# <AxesSubplot:>

# %%
df.loc[df["num_lab_procedures"]>95,"num_lab_procedures"]=np.mean(df["num_lab_procedures"])

# %%
df["num_lab_procedures"].plot.box()
# Out:
# <AxesSubplot:>

# %%
df["num_procedures"].plot.box()
# Out:
# <AxesSubplot:>

# %%
df.loc[df["num_procedures"]>5,"num_procedures"]=np.mean(df["num_procedures"])

# %%
df.loc[df["number_diagnoses"]>13,"number_diagnoses"]=np.mean(df["number_diagnoses"])
df["number_diagnoses"].plot.box()
# Out:
# <AxesSubplot:>

# %%
fig=plt.figure(figsize=(15,15))
ax=fig.gca()
df.hist(ax=ax,color="green")
plt.show()
# Out:
# <ipython-input-128-c1c3901bb8bf>:3: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   df.hist(ax=ax,color="green")

# %%
import seaborn as sns
categorical_features=['race', 'gender', 'age',
       'admission_type_id', 'discharge_disposition_id', 'admission_source_id',
       
          'max_glu_serum', 'A1Cresult',
        'glipizide',
        'rosiglitazone', 
        'change', 'diabetesMed', 'readmitted']
for i in categorical_features:
    sns.countplot(x = i, hue = "readmitted", data = df)
    
    plt.show()

# %%
new_cate= {1.0:"Emergency",
          2.0:"Emergency",
          3.0:"Elective",
          4.0:"New Born",
          5.0:"Other",
          6.0:"Other",
          7.0:"Trauma Center",
          8.0:"Other"}
df["admission_type_id"]=df["admission_type_id"].replace(new_cate)
sns.countplot(x = "admission_type_id", data = df)
plt.title("Distribution of Admission IDs")
plt.show()
sns.countplot(x = "admission_type_id", hue = "readmitted", data = df)
plt.title("admission_type_id - Readmitted")
plt.show()

# %%
df["discharge_disposition_id"].value_counts()
# Out:
# 1     44315
# 3      8784
# 6      8289
# 18     2474
# 2      1539
# 22     1409
# 11     1077
# 5       913
# 25      778
# 4       541
# 7       409
# 23      260
# 13      243
# 14      218
# 28       90
# 8        73
# 15       40
# 24       25
# 9         9
# 17        8
# 10        6
# 19        6
# 27        3
# 16        3
# 12        2
# 20        1
# Name: discharge_disposition_id, dtype: int64

# %%
new_cate1 = {1:"Discharged to Home",
                    6:"Discharged to Home",
                    8:"Discharged to Home",
                    13:"Discharged to Home",
                    19:"Discharged to Home",
                    18:"Other",25:"Other",26:"Other",
                    2:"Other",3:"Other",4:"Other",
                    5:"Other",7:"Other",9:"Other",
                    10:"Other",11:"Other",12:"Other",
                    14:"Other",15:"Other",16:"Other",
                    17:"Other",20:"Other",21:"Other",
                    22:"Other",23:"Other",24:"Other",
                    27:"Other",28:"Other",29:"Other",30:"Other"}

df["discharge_disposition_id"] = df["discharge_disposition_id"].replace(new_cate1)
sns.countplot(x = "discharge_disposition_id", data = df)
plt.title("Distribution of discharge IDs")
plt.show()

# %%
mapped_adm = {1:"Referral",2:"Referral",3:"Referral",
              4:"Other",5:"Other",6:"Other",10:"Other",22:"Other",25:"Other",
              9:"Other",8:"Other",14:"Other",13:"Other",11:"Other",
              15:"Other",17:"Other",20:"Other",21:"Other",
              7:"Emergency"}
df.admission_source_id = df.admission_source_id.replace(mapped_adm)

sns.countplot(x = "admission_source_id", data = df)
plt.show()

sns.countplot(x = "admission_source_id", hue = "readmitted", data = df)
plt.title("Admission Source - Readmitted")
plt.show()

# %%
fig = plt.figure(figsize=(13,7),)
ax=sns.kdeplot(df.loc[(df['readmitted'] == 0),'time_in_hospital'] , color='b',shade=True,label='Not Readmitted')
ax=sns.kdeplot(df.loc[(df['readmitted'] == 1),'time_in_hospital'] , color='r',shade=True, label='Readmitted')
ax.set(xlabel='Time in Hospital', ylabel='Frequency')
plt.title('Time in Hospital VS. Readmission')
# Out:
# Text(0.5, 1.0, 'Time in Hospital VS. Readmission')

# %%
sns.scatterplot(x=df["num_lab_procedures"],y=df["num_procedures"],hue=df["num_medications"])
# Out:
# <AxesSubplot:xlabel='num_lab_procedures', ylabel='num_procedures'>

# %%
sns.scatterplot(x=df["num_lab_procedures"],y=df["num_procedures"],hue=df["facility_usage"])
# Out:
# <AxesSubplot:xlabel='num_lab_procedures', ylabel='num_procedures'>

# %%
fig, ax = plt.subplots(figsize=(30, 30))

ax = sns.violinplot(x="readmitted", y="num_lab_procedures", data=df)

# %%
fig, ax = plt.subplots(figsize=(30, 30))

ax = sns.violinplot(x="readmitted", y="number_diagnoses", data=df)

# %%
fig, ax = plt.subplots(figsize=(30, 30))

ax = sns.violinplot(x="readmitted", y="facility_usage", data=df)

# %%
plt.figure(figsize = (10,5))
df.groupby(['A1Cresult'])['num_lab_procedures'].sum().sort_values(ascending = False).head(10).plot(kind = 'bar', color = 'teal')

plt.xticks(rotation=90)
plt.ylabel("num_lab_procedures")
plt.show()

# %%
plt.figure(figsize = (10,5))
df.groupby(['max_glu_serum'])['num_lab_procedures'].sum().sort_values(ascending = False).head(10).plot(kind = 'bar', color = 'teal')

plt.xticks(rotation=90)
plt.show()

# %%
df.head().T
# Out:
#                                   0          1                2          3  \
# encounter_id                2278392     149190            64410     500364
# patient_nbr                 8222157   55629189         86047875   82442376
# race                      Caucasian  Caucasian  AfricanAmerican  Caucasian
# gender                       Female     Female           Female       Male
# age                          [0-10)    [10-20)          [20-30)    [30-40)
# admission_type_id                 6          1                1          1
# discharge_disposition_id         25          1                1          1
# admission_source_id               1          7                7          7
# time_in_hospital                  1          3                2          2
# num_lab_procedures               41         59               11         44
# num_procedures                    0          0                5          1
# ...

# %%
from sklearn import preprocessing

# %%
categorical_features=['race', 'gender', 'age',
       'admission_type_id', 'discharge_disposition_id', 'admission_source_id',
       
          'max_glu_serum', 'A1Cresult',
        'glipizide',
        'rosiglitazone', 
        'change', 'diabetesMed', 'readmitted']

# %%
labelEncoder = preprocessing.LabelEncoder()

# %%
mapping_dict ={}
for col in categorical_features: 
    df[col] = labelEncoder.fit_transform(df[col]) 
  
    le_name_mapping = dict(zip(labelEncoder.classes_, 
                        labelEncoder.transform(labelEncoder.classes_))) 
  
    mapping_dict[col]= le_name_mapping 
print(mapping_dict)
# Out:
# {'race': {'AfricanAmerican': 0, 'Asian': 1, 'Caucasian': 2, 'Hispanic': 3, 'Other': 4}, 'gender': {'Female': 0, 'Male': 1}, 'age': {'[0-10)': 0, '[10-20)': 1, '[20-30)': 2, '[30-40)': 3, '[40-50)': 4, '[50-60)': 5, '[60-70)': 6, '[70-80)': 7, '[80-90)': 8, '[90-100)': 9}, 'admission_type_id': {'1': 0, '2': 1, '3': 2, '4': 3, '5': 4, '6': 5, '7': 6, '8': 7}, 'discharge_disposition_id': {'1': 0, '10': 1, '11': 2, '12': 3, '13': 4, '14': 5, '15': 6, '16': 7, '17': 8, '18': 9, '19': 10, '2': 11, '20': 12, '22': 13, '23': 14, '24': 15, '25': 16, '27': 17, '28': 18, '3': 19, '4': 20, '5': 21, '6': 22, '7': 23, '8': 24, '9': 25}, 'admission_source_id': {'1': 0, '10': 1, '11': 2, '13': 3, '14': 4, '17': 5, '2': 6, '20': 7, '22': 8, '25': 9, '3': 10, '4': 11, '5': 12, '6': 13, '7': 14, '8': 15, '9': 16}, 'max_glu_serum': {'>200': 0, '>300': 1, 'None': 2, 'Norm': 3}, 'A1Cresult': {'>7': 0, '>8': 1, 'None': 2, 'Norm': 3}, 'glipizide': {'Down': 0, 'No': 1, 'Steady': 2, 'Up': 3}, 'rosiglitazone':
# ...

# %%
plt.figure(figsize=(30,20))
cor = df.corr()
sns.heatmap(cor,vmax=1,square = True,annot=True, cmap=plt.cm.Blues)
plt.title('Correlation between different attributes')
plt.show()

# %%
#Correlation with output variable
cor_target = abs(cor["readmitted"])
#Selecting highly correlated features
relevant_features = cor_target[cor_target>0.02]
relevant_features
# Out:
# encounter_id                0.102392
# patient_nbr                 0.066844
# age                         0.063993
# admission_type_id           0.020218
# discharge_disposition_id    0.068482
# admission_source_id         0.028417
# time_in_hospital            0.059054
# num_lab_procedures          0.046700
# num_procedures              0.025079
# num_medications             0.034149
# number_diagnoses            0.101411
# glipizide                   0.023487
# rosiglitazone               0.022745
# change                      0.039329
# diabetesMed                 0.063784
# readmitted                  1.000000
# facility_usage              0.134701
# Name: readmitted, dtype: float64

# %%
target=df["readmitted"]
df.drop("readmitted",axis=1,inplace=True)

# %%
y = target
X = df

# %%
y
# Out:
# 0         0
# 1         1
# 2         0
# 3         0
# 4         0
#          ..
# 101754    1
# 101755    1
# 101756    1
# 101758    0
# 101765    0
# Name: readmitted, Length: 71515, dtype: int64

# %%
X
# Out:
#         encounter_id  patient_nbr  race  gender  age  admission_type_id  \
# 0            2278392      8222157     2       0    0                  5
# 1             149190     55629189     2       0    1                  0
# 2              64410     86047875     0       0    2                  0
# 3             500364     82442376     2       1    3                  0
# 4              16680     42519267     2       1    4                  0
# ...              ...          ...   ...     ...  ...                ...
# 101754     443842016    183087545     2       0    7                  0
# 101755     443842022    188574944     4       0    4                  0
# 101756     443842070    140199494     4       0    6                  0
# 101758     443842340    120975314     2       0    8                  0
# 101765     443867222    175429310     2       1    7                  0
#
#         discharge_disposition_id  admission_source_id  time_in_hospital  \
# ...

# %%
from imblearn.over_sampling import SMOTE
from collections import Counter

# %%
from sklearn.model_selection import train_test_split

# %%
print('Original dataset shape {}'.format(Counter(y)))
smt = SMOTE(random_state=20)
train_input_new, train_output_new = smt.fit_sample(X, y)
print('New dataset shape {}'.format(Counter(train_output_new)))
train_input_new = pd.DataFrame(train_input_new, columns = list(X.columns))
X_train, X_test, y_train, y_test = train_test_split(train_input_new, train_output_new, test_size=0.20, random_state=0)
# Out:
# Original dataset shape Counter({0: 42982, 1: 28533})
# New dataset shape Counter({0: 42982, 1: 42982})

# %%
from sklearn.ensemble import RandomForestClassifier
rm = RandomForestClassifier(n_estimators = 15, max_depth=25, criterion = "gini", min_samples_split=10)
rm.fit(X,y )
# Out:
# RandomForestClassifier(max_depth=25, min_samples_split=10, n_estimators=15)

# %%
rm_prd = rm.predict(X_test)
pd.crosstab(pd.Series(y_test, name = 'Actual'), pd.Series(rm_prd, name = 'Predict'), margins = True)
# Out:
# Predict     0     1   All
# Actual
# 0        1281   684  1965
# 1         917   521  1438
# All      2198  1205  3403

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score

# %%
print("Accuracy is {0:.2f}".format(accuracy_score(y_test, rm_prd)))
print("Precision is {0:.2f}".format(precision_score(y_test, rm_prd)))
print("Recall is {0:.2f}".format(recall_score(y_test, rm_prd)))

accuracy_rm = accuracy_score(y_test, rm_prd)
precision_rm = precision_score(y_test, rm_prd)
recall_rm = recall_score(y_test, rm_prd)
# Out:
# Accuracy is 0.83
# Precision is 0.95
# Recall is 0.69

# %%
rm_prd
# Out:
# array([0, 0, 1, ..., 0, 1, 0], dtype=int64)

# %%
import pickle
pickle.dump(rm, open('d.pkl','wb'))

# %%
model = pickle.load(open('d.pkl','rb'))
